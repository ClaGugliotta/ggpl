# %% [markdown]
# Laboratorio
# ===========
#
# Esempio 1
# ------------
# prima esempio

# %%
from pyplasm import *
# Out:
# Evaluating fenvs.py..
# ...fenvs.py imported in 0.011653 seconds

# %%
VIEW(CUBE(1))

# %% [markdown]
# ![CUBE.png](attachment:CUBE.png)

# %% [markdown]
# Integrale di volume sul dominio $D$ del monomio $x^\alpha y^\beta z^\gamma$
# $$\int_D x^\alpha y^\beta z^\gamma dV$$

# %%
import numpy 
import numpy as np 
help(numpy)
